# %% [markdown]
# ## Topics
# 1. How to set up the vs code project?
# 2. How to setup the libopencm3 repo
# 3. Adjusting make files and stuff
# 4. Building using gcc
# 5. Flashing using st-flash

# %% [markdown]
# ![image][images/]
